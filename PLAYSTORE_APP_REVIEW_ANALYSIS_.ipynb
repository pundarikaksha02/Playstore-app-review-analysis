# %% [markdown]
# <a href="https://colab.research.google.com/github/pundarikaksha02/Playstore-app-review-analysis/blob/main/PLAYSTORE_APP_REVIEW_ANALYSIS_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - PLAYSTORE APP REVIEW ANALYSIS

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Pundarikaksha S

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Data science can be summarized into five steps: capture, maintain process, analyze, and communicate. The analysis of Google Play Store application aided to build most reliable and more interactive applications. This would be very useful for app developers to build an application focused on certain discussed category in this analysis. This analysis will help in building the application with precise and accurate objectives.
# In the initial phase, we focused more on the problem statements and data cleaning, in order to ensure that we give them the best results out of our analysis. Our major challenge was data cleaning, In Data Cleaning, we have performed few steps to ensure the data quality such as removing NAN values. During the Data Cleaning step we found that 13.60% of reviews were NaN values, and even after merging both the data frames, we could not infer much in order to fill them. Thus, we had to drop them.
#
# The merged data frame of both play store and user reviews, had only 816 common apps. This is just 10% of the cleaned data, we could have given more valuable analysis if we had at least 70% - 80% of the data available in the merged data frames.
#
# User Reviews had 42% of NaN values, which could have been used for developing an understanding of the category wise sentiments, which would help us to fill 13.60% NaN values of the Reviews column.
#
# With the cleaned data, we have performed Exploratory Data Analysis to understand our dataset like number of installations for each category We explore the correlation between the size of the app and the version of Android on the number of installs and so on.
#
# Our motive in whole project was to analyze the data and find out main components that affect users’ decision to download app. After completion of analysis I concluded that user prefer more of free apps. Most of the apps present in play store are more or less of same size so size doesn’t affect their decision much.
#
# It was found that Most of the apps that are  present on the google play store have rating  in between 4 and 5.Also it was observed that Maximum number of applications present in the dataset are of small size.
#
# We found most popular category of apps on two basis - Number of Installs and Number of reviews. Personalization wins in former criteria whereas Sports wins in later criteria.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here: https://github.com/pundarikaksha02

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**
#
# 1) What are the top categories on Play Store?
#
# 2) Are majority of the apps Paid or Free?
#
# 3) How importance is the rating of the application?
#
# 4) Which categories from the audience should the app be based on?
#
# 5) Which category has the most no. of installations?
#
# 6) How does the count of apps varies by Genres?
#
# 7) How does the last update has an effect on the rating?
#
# 8) How are ratings affected when the app is a paid one?
#
# 9) How are reviews and ratings co-related?
#
# 10) Lets us discuss the sentiment subjectivity.
#
# 11) Is subjectivity and polarity proportional to each other?
#
# 12) What is the percentage of review sentiments?
#
# 13) How is sentiment polarity varying for paid and free apps?

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To help with building their technical know how about building a good android application. They wanted us to study current trends and insights of Play Store.
#
# We were given with two datasets i.e., Play Store & User Reviews. Before jumping into the data's provided, let me first explain you about the EDA analysis.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset
ps_df = pd.read_csv('/content/drive/MyDrive/access data/Play Store Data.csv')
ur_df = pd.read_csv('/content/drive/MyDrive/access data/User Reviews.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
ps_df.head().T
# Out:
#                                                              0  \
# App             Photo Editor & Candy Camera & Grid & ScrapBook
# Category                                        ART_AND_DESIGN
# Rating                                                     4.1
# Reviews                                                    159
# Size                                                       19M
# Installs                                               10,000+
# Type                                                      Free
# Price                                                        0
# Content Rating                                        Everyone
# Genres                                            Art & Design
# Last Updated                                   January 7, 2018
# Current Ver                                              1.0.0
# Android Ver                                       4.0.3 and up
#
#                                         1  \
# ...

# %%
ur_df.head().T
# Out:
#                                                                         0  \
# App                                                 10 Best Foods for You
# Translated_Review       I like eat delicious food. That's I'm cooking ...
# Sentiment                                                        Positive
# Sentiment_Polarity                                                    1.0
# Sentiment_Subjectivity                                           0.533333
#
#                                                                       1  \
# App                                               10 Best Foods for You
# Translated_Review       This help eating healthy exercise regular basis
# Sentiment                                                      Positive
# Sentiment_Polarity                                                 0.25
# Sentiment_Subjectivity                                         0.288462
#
#                                             2  \
# ...

# %%
ps_df.tail().T
# Out:
#                            10836                             10837  \
# App             Sya9a Maroc - FR  Fr. Mike Schmitz Audio Teachings
# Category                  FAMILY                            FAMILY
# Rating                       4.5                               5.0
# Reviews                       38                                 4
# Size                         53M                              3.6M
# Installs                  5,000+                              100+
# Type                        Free                              Free
# Price                          0                                 0
# Content Rating          Everyone                          Everyone
# Genres                 Education                         Education
# Last Updated       July 25, 2017                      July 6, 2018
# Current Ver                 1.48                               1.0
# Android Ver           4.1 and up                        4.1 and up
#
# ...

# %%
ur_df.tail().T
# Out:
#                                               64290  \
# App                     Houzz Interior Design Ideas
# Translated_Review                               NaN
# Sentiment                                       NaN
# Sentiment_Polarity                              NaN
# Sentiment_Subjectivity                          NaN
#
#                                               64291  \
# App                     Houzz Interior Design Ideas
# Translated_Review                               NaN
# Sentiment                                       NaN
# Sentiment_Polarity                              NaN
# Sentiment_Subjectivity                          NaN
#
#                                               64292  \
# App                     Houzz Interior Design Ideas
# Translated_Review                               NaN
# Sentiment                                       NaN
# Sentiment_Polarity                              NaN
# Sentiment_Subjectivity                          NaN
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
ps_df.shape
# Out:
# (10841, 13)

# %%
ur_df.shape
# Out:
# (64295, 5)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
ps_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
ur_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
ps_df.duplicated().sum()
# Out:
# 483

# %%
ur_df.duplicated().sum()
# Out:
# 33616

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
ps_df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
ur_df.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(ps_df.isnull(),cmap='Blues')
plt.title('Missing values heatmap')
plt.show()

# %%
sns.heatmap(ur_df.isnull(),cmap='Blues')
plt.title('Missing values heatmap')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
ps_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
ur_df.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
# Dataset Describe
ps_df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# play_store dataframe has 10841 rows and 13 columns. The 13 columns are identified as below:
#
# App - It tells us about the name of the application.
#
# Category - It tells us about the category to which an application belongs.
#
# Rating - It tells us about the ratings given by the users for a specific application.
#
# Reviews - It tells us about the total number of users who have given a review for the application.
#
# Size - It tells us about the size being occupied the application on the mobile phone.
#
# Installs - It tells us about the total number of installs/downloads for an application.
#
# Type - It tells us whether the application is free or a paid one.
#
# Price - It tells us about the price of the application.
#
# Content_Rating - It tells us about the target audience for the application.
#
# Genres - It tells us about the various other categories to which an application can belong.
#
# Last_Updated - It tells us about the when the application was updated.
#
# Current_Ver - It tells us about the current version of the application.
#
# Android_Ver - It tells us about the android version which can support the application on its platform.

# %%
def PSinfo():
    temp = pd.DataFrame(index=ps_df.columns)
    temp['data_type'] = ps_df.dtypes
    temp["count of non null values"] = ps_df.count()
    temp['NaN values'] = ps_df.isnull().sum()
    temp['% NaN values'] = (temp['NaN values']/len(ps_df)).round(4)*100 # or ps_df.isnull().mean()
    temp['unique_count'] = ps_df.nunique()
    return temp 
PSinfo()
# Out:
#                data_type  count of non null values  NaN values  % NaN values  \
# App               object                     10841           0          0.00
# Category          object                     10841           0          0.00
# Rating           float64                      9367        1474         13.60
# Reviews           object                     10841           0          0.00
# Size              object                     10841           0          0.00
# Installs          object                     10841           0          0.00
# Type              object                     10840           1          0.01
# Price             object                     10841           0          0.00
# Content Rating    object                     10840           1          0.01
# Genres            object                     10841           0          0.00
# Last Updated      object                     10841           0          0.00
# ...

# %% [markdown]
# FINDINGS

# %% [markdown]
# The number of null values are:
#
# Rating has 1474 null values which contributes 13.60% of the data.
#
# Type has 1 null value which contributes 0.01% of the data.
#
# Content_Rating has 1 null value which contributes 0.01% of the data.
#
# Current_Ver has 8 null values which contributes 0.07% of the data.
#
# Android_Ver has 3 null values which contributes 0.03% of the data.

# %%
ur_df.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# user_reviews dataframe has 64295 rows and 5 columns. The 5 columns are identified as follows:
#
# App - It tells us about the name of the application.
#
# Translated_Review - It tells us about what the users feedback is about the application.
#
# Sentiment - It tells us about a view or opinion of the user w.r.t. the application.
#
# Sentiment_Polarity - Sentiment polarity for an element defines the orientation of the expressed sentiment, i.e., it determines if the text expresses the positive, negative or neutral sentiment of the user about the application.
#
# Sentiment_Subjectivity - It refers to the text that contains text which is usually expressed by a human having typical moods, emotions, and feelings. Mostly it is a public opinion and not a factual information.

# %%
def URinfo():
    temp = pd.DataFrame(index=ur_df.columns)
    temp['data_type'] = ur_df.dtypes
    temp["count of non null values"] = ur_df.count()
    temp['NaN values'] = ur_df.isnull().sum()
    temp['% NaN values'] = (temp['NaN values']/len(ur_df)).round(4)*100 # or ur_df.isnull().mean()
    temp['unique_count'] = ur_df.nunique()
    return temp 
URinfo()
# Out:
#                        data_type  count of non null values  NaN values  \
# App                       object                     64295           0
# Translated_Review         object                     37427       26868
# Sentiment                 object                     37432       26863
# Sentiment_Polarity       float64                     37432       26863
# Sentiment_Subjectivity   float64                     37432       26863
#
#                         % NaN values  unique_count
# App                             0.00          1074
# Translated_Review              41.79         27994
# Sentiment                      41.78             3
# Sentiment_Polarity             41.78          5410
# Sentiment_Subjectivity         41.78          4474

# %% [markdown]
# FINDINGS

# %% [markdown]
# The number of null values are:
#
# Translated_Review has 26868 null values which contributes 41.79% of the data.
#
# Sentiment has 26863 null values which contributes 41.78% of the data.
#
# Sentiment_Polarity has 26863 null values which contributes 41.78% of the data.
#
# Sentiment_Subjectivity has 26863 null values which contributes 41.78% of the data.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for col in ps_df.columns:
  print(ps_df[col].unique())
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook' 'Coloring book moana'
#  'U Launcher Lite – FREE Live Cool Themes, Hide Apps' ...
#  'Parkinson Exercices FR' 'The SCP Foundation DB fr nn5n'
#  'iHoroscope - 2018 Daily Horoscope & Astrology']
# ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD_AND_DRINK' 'HEALTH_AND_FITNESS' 'HOUSE_AND_HOME'
#  'LIBRARIES_AND_DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL_AND_LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO_PLAYERS'
#  'NEWS_AND_MAGAZINES' 'MAPS_AND_NAVIGATION' '1.9']
# [ 4.1  3.9  4.7  4.5  4.3  4.4  3.8  4.2  4.6  3.2  4.   nan  4.8  4.9
#   3.6  3.7  3.3  3.4  3.5  3.1  5.   2.6  3.   1.9  2.5  2.8  2.7  1.
#   2.9  2.3  2.2  1.7  2.   1.8  2.4  1.6  2.1  1.4  1.5  1.2 19. ]
# ['159' '967' '87510' ... '603' '1195' '398307']
# ...

# %%
for col in ur_df.columns:
  print(ur_df[col].unique())
# Out:
# ['10 Best Foods for You' '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室' '11st' ...
#  'Hotwire Hotel & Car Rental App' 'Housing-Real Estate & Property'
#  'Houzz Interior Design Ideas']
# ['I like eat delicious food. That\'s I\'m cooking food myself, case "10 Best Foods" helps lot, also "Best Before (Shelf Life)"'
#  'This help eating healthy exercise regular basis' nan ...
#  'Dumb app, I wanted post property rent give option. Website work. Waste time space phone.'
#  'I property business got link SMS happy performance still guys need raise bar guys Cheers'
#  'Useless app, I searched flats kondapur, Hyderabad . None number reachable I know flats unavailable would keep posts active']
# ['Positive' nan 'Neutral' 'Negative']
# [ 1.          0.25               nan ... -0.52857143 -0.37777778
#   0.17333333]
# [0.53333333 0.28846154        nan ... 0.51145833 0.7172619  0.2594697 ]

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
#missing values in user_review df
URinfo()
# Out:
#                        data_type  count of non null values  NaN values  \
# App                       object                     64295           0
# Translated_Review         object                     37427       26868
# Sentiment                 object                     37432       26863
# Sentiment_Polarity       float64                     37432       26863
# Sentiment_Subjectivity   float64                     37432       26863
#
#                         % NaN values  unique_count
# App                             0.00          1074
# Translated_Review              41.79         27994
# Sentiment                      41.78             3
# Sentiment_Polarity             41.78          5410
# Sentiment_Subjectivity         41.78          4474

# %%
# creating new_UR DF
# We have dropped the rows having all null values as it makes no sense in keeping them
new_UR = ur_df.dropna(subset=["Translated_Review","Sentiment","Sentiment_Polarity","Sentiment_Subjectivity"],how="all")

# %%
new_UR.shape
# Out:
# (37432, 5)

# %%
new_UR.isnull().sum()
# Out:
# App                       0
# Translated_Review         5
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
new_UR[new_UR.Translated_Review.isnull()]
# Out:
#                                              App Translated_Review Sentiment  \
# 268                                         11st               NaN   Neutral
# 15048        Birds Sounds Ringtones & Wallpapers               NaN   Neutral
# 22092             Calorie Counter - MyFitnessPal               NaN   Neutral
# 31623                                  DC Comics               NaN   Neutral
# 52500  Garden Photo Frames - Garden Photo Editor               NaN   Neutral
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 268                   0.0                     0.0
# 15048                 0.0                     0.0
# 22092                 0.0                     0.0
# 31623                 0.0                     0.0
# 52500                 0.0                     0.0

# %%
new_UR = new_UR.dropna(subset= ["Translated_Review"],how = "all")
new_UR.shape
# Out:
# (37427, 5)

# %%
def New_URinfo():
    temp = pd.DataFrame(index=new_UR.columns)
    temp['data_type'] = new_UR.dtypes
    temp["count of non null values"] = new_UR.count()
    temp['NaN values'] = new_UR.isnull().sum()
    temp['% NaN values'] = (temp['NaN values']/len(new_UR)).round(4)*100 # or new_UR.isnull().mean()
    temp['unique_count'] = new_UR.nunique()
    return temp 
New_URinfo()
# Out:
#                        data_type  count of non null values  NaN values  \
# App                       object                     37427           0
# Translated_Review         object                     37427           0
# Sentiment                 object                     37427           0
# Sentiment_Polarity       float64                     37427           0
# Sentiment_Subjectivity   float64                     37427           0
#
#                         % NaN values  unique_count
# App                              0.0           865
# Translated_Review                0.0         27994
# Sentiment                        0.0             3
# Sentiment_Polarity               0.0          5410
# Sentiment_Subjectivity           0.0          4474

# %% [markdown]
# From the above output we can infer that we have removed all the NaN values from the user_review data frame.

# %% [markdown]
# #Missing value in playstore df

# %%
# If any columns have 90% ofthe data missing then we can drop that column.

print(len(ps_df)*0.9) # 90% of data will be 9756
ps_df.isnull().sum()

# From the below output we can infer that no columns has 9756 NaN values 
# so we need not to Drop any Columns in this DataFrame.
# Out:
# 9756.9
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# Lets check whether we have NAN values in all of the 5 columns which has NaN in each row. 

ps_df.dropna(subset=["Rating","Type","Content Rating","Current Ver","Android Ver"],how="all").shape

# since the shape of the output remains as original that means we dont have any rows where all of this values are NAN.
# Out:
# (10841, 13)

# %%
PSinfo()
# Out:
#                data_type  count of non null values  NaN values  % NaN values  \
# App               object                     10841           0          0.00
# Category          object                     10841           0          0.00
# Rating           float64                      9367        1474         13.60
# Reviews           object                     10841           0          0.00
# Size              object                     10841           0          0.00
# Installs          object                     10841           0          0.00
# Type              object                     10840           1          0.01
# Price             object                     10841           0          0.00
# Content Rating    object                     10840           1          0.01
# Genres            object                     10841           0          0.00
# Last Updated      object                     10841           0          0.00
# ...

# %% [markdown]
# From the above information we can see that 13.60% of data are missing in the Rating Column.

# %%
ps_df[ps_df["Rating"].isnull()].shape
# Out:
# (1474, 13)

# %% [markdown]
# Lets Merge Two DataFrames based on common "App" Column.

# %%
# Lets Merge two DataFrame to check the common apps 
ps_copy = ps_df.copy()
ur_copy = new_UR.copy()

# %%
merged_PS_UR = pd.merge(ps_copy, ur_copy, how='inner', left_on='App', right_on='App')

# %%
def Mergedinfo():
    temp = pd.DataFrame(index=merged_PS_UR.columns)
    temp['data_type'] = merged_PS_UR.dtypes
    temp["count of non null values"] = merged_PS_UR.count()
    temp['NaN values'] = merged_PS_UR.isnull().sum()
    temp['% NaN values'] = (temp['NaN values']/len(merged_PS_UR)).round(4)*100 # or merged_PS_UR.isnull().mean()
    temp['unique_count'] = merged_PS_UR.nunique()
    return temp 
Mergedinfo()
# Out:
#                        data_type  count of non null values  NaN values  \
# App                       object                     72605           0
# Category                  object                     72605           0
# Rating                   float64                     72566          39
# Reviews                   object                     72605           0
# Size                      object                     72605           0
# Installs                  object                     72605           0
# Type                      object                     72605           0
# Price                     object                     72605           0
# Content Rating            object                     72605           0
# Genres                    object                     72605           0
# Last Updated              object                     72605           0
# Current Ver               object                     72605           0
# ...

# %% [markdown]
# From the Above info we can infer that we have 39 missing values in Rating Column

# %%
print(ps_df.App.nunique())
print(new_UR.App.nunique())
print(Mergedinfo()["unique_count"]["App"])
# Out:
# 9660
# 865
# 816

# %% [markdown]
# From the Above output we can see that we have 9660 unique Apps in Playstore DF.865 unique Apps in UserReview DF.

# %% [markdown]
# From the Merged DF we can infer that, we have only 816 Common Apps between Two DF's.

# %%
merged_PS_UR[merged_PS_UR.Rating.isnull()]
# Out:
#                   App Category  Rating Reviews  Size Installs  Type Price  \
# 47874  Blood Pressure  MEDICAL     NaN      10  2.4M   1,000+  Free     0
# 47875  Blood Pressure  MEDICAL     NaN      10  2.4M   1,000+  Free     0
# 47876  Blood Pressure  MEDICAL     NaN      10  2.4M   1,000+  Free     0
# 47877  Blood Pressure  MEDICAL     NaN      10  2.4M   1,000+  Free     0
# 47878  Blood Pressure  MEDICAL     NaN      10  2.4M   1,000+  Free     0
# 47879  Blood Pressure  MEDICAL     NaN      10  2.4M   1,000+  Free     0
# 47880  Blood Pressure  MEDICAL     NaN      10  2.4M   1,000+  Free     0
# 47881  Blood Pressure  MEDICAL     NaN      10  2.4M   1,000+  Free     0
# 47882  Blood Pressure  MEDICAL     NaN      10  2.4M   1,000+  Free     0
# 47883  Blood Pressure  MEDICAL     NaN      10  2.4M   1,000+  Free     0
# 47884  Blood Pressure  MEDICAL     NaN      10  2.4M   1,000+  Free     0
# 47885  Blood Pressure  MEDICAL     NaN      10  2.4M   1,000+  Free     0
# ...

# %%
l = len(merged_PS_UR[merged_PS_UR.Rating.isnull()]) # 39
l1 = len(merged_PS_UR[(merged_PS_UR.Rating.isnull()) & (merged_PS_UR["Sentiment"].str.contains("Positive"))]) # 31
l2 = len(merged_PS_UR[(merged_PS_UR.Rating.isnull()) & (merged_PS_UR["Sentiment"].str.contains("Negative"))]) # 4
l3 = len(merged_PS_UR[(merged_PS_UR.Rating.isnull()) & (merged_PS_UR["Sentiment"].str.contains("Neutral"))]) # 4

positive_per = round((l1/l)*100,2)
negative_per = round((l2/l)*100,2)
Neutral_per = round((l3/l)*100,2)

print(positive_per,negative_per,Neutral_per)
# Out:
# 79.49 10.26 10.26

# %%
merged_PS_UR.Sentiment.unique()
# Out:
# array(['Negative', 'Neutral', 'Positive'], dtype=object)

# %% [markdown]
# From the above output we can infer that the App for which Rating are NaN is "Blood Pressure" and rest of the values are also same out of which Sentiment column has - 10% of negative and 10% are neutral 80% are positive values for the App "Blood Pressure"

# %% [markdown]
# Let us now check the rating NaN values in play_store DF

# %%
ps_df[ps_df["Rating"].isnull() & ps_df["Category"].str.contains("MEDICAL") & ps_df["App"].str.contains("Blood Pressure")]
# Out:
#                       App Category  Rating Reviews  Size Installs  Type Price  \
# 2356  Free Blood Pressure  MEDICAL     NaN       7  5.7M   5,000+  Free     0
# 2502  Free Blood Pressure  MEDICAL     NaN       7  5.7M   5,000+  Free     0
# 2513       Blood Pressure  MEDICAL     NaN      10  2.4M   1,000+  Free     0
# 6598  Free Blood Pressure  MEDICAL     NaN       7  5.7M   5,000+  Free     0
#
#      Content Rating   Genres      Last Updated Current Ver   Android Ver
# 2356       Everyone  Medical  October 13, 2016       3.0.0  4.0.3 and up
# 2502       Everyone  Medical  October 13, 2016       3.0.0  4.0.3 and up
# 2513       Everyone  Medical    March 14, 2015         1.0    2.3 and up
# 6598       Everyone  Medical  October 13, 2016       3.0.0  4.0.3 and up

# %%
mode_value = ps_df.Rating.mode()[0]
mode_value
# Out:
# 4.4

# %% [markdown]
# ince in the Merged DF , the Sentiment column has - 10% of negative and 10% are neutral 80% are positive values for the App "Blood Pressure" Hence since we have 80% of positive reviews for "Blood Pressure App" we can fill the NaN of rating with mode value "4.4"

# %%
ps_df.loc[2513] = ps_df.loc[2513].fillna(mode_value)

# %%
ps_df.iloc[2513]
# Out:
# App               Blood Pressure
# Category                 MEDICAL
# Rating                       4.4
# Reviews                       10
# Size                        2.4M
# Installs                  1,000+
# Type                        Free
# Price                          0
# Content Rating          Everyone
# Genres                   Medical
# Last Updated      March 14, 2015
# Current Ver                  1.0
# Android Ver           2.3 and up
# Name: 2513, dtype: object

# %%
# This is just for confirmation after filling one NaN Rating. 

print(f'The shape of Play_Store DF having NaN Ratings are : {ps_df[ps_df["Rating"].isnull()].shape}')
ps_df[ps_df["Rating"].isnull() & ps_df["Category"].str.contains("MEDICAL") & ps_df["App"].str.contains("Blood Pressure")]
# Out:
# The shape of Play_Store DF having NaN Ratings are : (1473, 13)
#                       App Category  Rating Reviews  Size Installs  Type Price  \
# 2356  Free Blood Pressure  MEDICAL     NaN       7  5.7M   5,000+  Free     0
# 2502  Free Blood Pressure  MEDICAL     NaN       7  5.7M   5,000+  Free     0
# 6598  Free Blood Pressure  MEDICAL     NaN       7  5.7M   5,000+  Free     0
#
#      Content Rating   Genres      Last Updated Current Ver   Android Ver
# 2356       Everyone  Medical  October 13, 2016       3.0.0  4.0.3 and up
# 2502       Everyone  Medical  October 13, 2016       3.0.0  4.0.3 and up
# 6598       Everyone  Medical  October 13, 2016       3.0.0  4.0.3 and up

# %%
# Unique Categories in the filtered DF where the ratings are null.

ps_df[ps_df["Rating"].isnull()]["Category"].unique()
# Out:
# array(['ART_AND_DESIGN', 'BEAUTY', 'BOOKS_AND_REFERENCE', 'BUSINESS',
#        'COMICS', 'DATING', 'EDUCATION', 'EVENTS', 'FOOD_AND_DRINK',
#        'HOUSE_AND_HOME', 'LIBRARIES_AND_DEMO', 'FAMILY', 'MEDICAL',
#        'TOOLS', 'PARENTING', 'VIDEO_PLAYERS', 'PERSONALIZATION', 'GAME',
#        'PHOTOGRAPHY', 'SOCIAL', 'SPORTS', 'COMMUNICATION', 'PRODUCTIVITY',
#        'AUTO_AND_VEHICLES', 'FINANCE', 'LIFESTYLE', 'TRAVEL_AND_LOCAL',
#        'SHOPPING', 'HEALTH_AND_FITNESS', 'WEATHER', 'NEWS_AND_MAGAZINES',
#        'MAPS_AND_NAVIGATION'], dtype=object)

# %%
ps_df.groupby(["Category"])["App"].nunique()
# Out:
# Category
# 1.9                       1
# ART_AND_DESIGN           64
# AUTO_AND_VEHICLES        85
# BEAUTY                   53
# BOOKS_AND_REFERENCE     222
# BUSINESS                420
# COMICS                   56
# COMMUNICATION           316
# DATING                  171
# EDUCATION               119
# ENTERTAINMENT           102
# EVENTS                   64
# FAMILY                 1909
# FINANCE                 345
# FOOD_AND_DRINK          112
# GAME                    960
# HEALTH_AND_FITNESS      288
# HOUSE_AND_HOME           74
# LIBRARIES_AND_DEMO       84
# LIFESTYLE               369
# MAPS_AND_NAVIGATION     131
# MEDICAL                 396
# NEWS_AND_MAGAZINES      254
# PARENTING                60
# PERSONALIZATION         376
# PHOTOGRAPHY             281
# PRODUCTIVITY            374
# SHOPPING                202
# SOCIAL                  239
# SPORTS                  327
# TOOLS                   829
# TRAVEL_AND_LOCAL        219
# ...

# %% [markdown]
# From the above we can see that number of unique Apps found in each category.
#
# Note: Ignore the 1.9 category name as of now.

# %%
ps_df.groupby(["Category"])["App"].count()
# Out:
# Category
# 1.9                       1
# ART_AND_DESIGN           65
# AUTO_AND_VEHICLES        85
# BEAUTY                   53
# BOOKS_AND_REFERENCE     231
# BUSINESS                460
# COMICS                   60
# COMMUNICATION           387
# DATING                  234
# EDUCATION               156
# ENTERTAINMENT           149
# EVENTS                   64
# FAMILY                 1972
# FINANCE                 366
# FOOD_AND_DRINK          127
# GAME                   1144
# HEALTH_AND_FITNESS      341
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       85
# LIFESTYLE               382
# MAPS_AND_NAVIGATION     137
# MEDICAL                 463
# NEWS_AND_MAGAZINES      283
# PARENTING                60
# PERSONALIZATION         392
# PHOTOGRAPHY             335
# PRODUCTIVITY            424
# SHOPPING                260
# SOCIAL                  295
# SPORTS                  384
# TOOLS                   843
# TRAVEL_AND_LOCAL        258
# ...

# %% [markdown]
# From the above we can see that number of total Apps found in each category.
#
# Note: Ignore the 1.9 category name as of now.

# %%
ps_df[(ps_df["Category"]== "AUTO_AND_VEHICLES") & (ps_df["App"].str.contains("FORD V SERIES CALC - NO LIMIT"))]
# Out:
#                                 App           Category  Rating Reviews Size  \
# 4697  FORD V SERIES CALC - NO LIMIT  AUTO_AND_VEHICLES     NaN       2  17M
#
#      Installs  Type  Price Content Rating           Genres   Last Updated  \
# 4697      50+  Paid  $9.99       Everyone  Auto & Vehicles  June 25, 2018
#
#      Current Ver Android Ver
# 4697       3.0.0  4.0 and up

# %% [markdown]
# If we compare the count of Apps and Unique count of Apps above we can get an idea that the count and unique count are almost equal in each category.

# %%
new_PS = ps_df.dropna(subset = ["Rating"],how= "all")

# %%
new_PS.shape
# Out:
# (9368, 13)

# %% [markdown]
# Let us check for any noises or irrelevant data in any of the Columns/Rows and perform the following on our play_store DF.
#
# 1) Reviews should be numeric type.
#
# 2) Size should be numeric type. In the given dataset it has 'M' and 'k' strings present in it. We need to convert these into numbers.
#
# 3) Installs should be numeric type. It has '+' & ',' characters present in it, which needs to be removed.
#
# 4) Price should be numeric type. It has '$' character present in it, which needs to be removed.
#
# 5) Current_Ver should be numeric type.
#
# 6) Android_Ver should be numeric type.
#
# 7) Junk Apps should be filtered out from the dataframe.
#
# Let us begin with the Category column

# %%
new_PS['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
# '1.9' is wrong value. So I have to see in which rows '1.9' corresponds to.
new_PS[new_PS['Category']== "1.9"]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
new_PS.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# From the above Output we can infer that in the rating column we have one outlier.
#
# since we have only rating as numeric, the boxplot is taking rating column.

# %%
new_PS['Rating'].unique()
# Out:
# array([ 4.1,  3.9,  4.7,  4.5,  4.3,  4.4,  3.8,  4.2,  4.6,  3.2,  4. ,
#         4.8,  4.9,  3.6,  3.7,  3.3,  3.4,  3.5,  3.1,  5. ,  2.6,  3. ,
#         1.9,  2.5,  2.8,  2.7,  1. ,  2.9,  2.3,  2.2,  1.7,  2. ,  1.8,
#         2.4,  1.6,  2.1,  1.4,  1.5,  1.2, 19. ])

# %%
# Working on Outlier found above.["19.0"]
new_PS[new_PS.Rating > 5]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
new_PS[new_PS['Content Rating'].isnull()] 
new_PS['Last Updated'].unique() # output has "1.0.19" in it.
new_PS['Type'].unique() # output = array(['Free', 'Paid', nan, '0'], dtype=object)10472 row has that 0 
new_PS["Genres"].unique() # output has "February 11, 2018" in it.
# Out:
# array(['Art & Design', 'Art & Design;Pretend Play',
#        'Art & Design;Creativity', 'Auto & Vehicles', 'Beauty',
#        'Books & Reference', 'Business', 'Comics', 'Comics;Creativity',
#        'Communication', 'Dating', 'Education;Education', 'Education',
#        'Education;Creativity', 'Education;Music & Video',
#        'Education;Action & Adventure', 'Education;Pretend Play',
#        'Education;Brain Games', 'Entertainment',
#        'Entertainment;Music & Video', 'Entertainment;Brain Games',
#        'Entertainment;Creativity', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Lifestyle;Pretend Play',
#        'Adventure;Action & Adventure', 'Arcade', 'Casual', 'Card',
#        'Casual;Pretend Play', 'Action', 'Strategy', 'Puzzle', 'Sports',
#        'Music', 'Word', 'Racing', 'Casual;Creativity',
#        'Casual;Action & Adventure', 'Simulation', 'Adventure', 'Board',
# ...

# %% [markdown]
# f we see the 10472 row and Last updated column we can see that it has different format compare to rest of the values, Type column has 0,Genres has date (noise),Android Ver has NaN value in the 10472 row.

# %% [markdown]
# After analysing the values against the given columns we came to conclusion that we can completely drop this row (10472) from the data set.

# %%
new_PS = new_PS.drop([10472])

# %%
new_PS.shape # 10472 has dropped
# Out:
# (9367, 13)

# %%
new_PS.boxplot()
# Out:
# <Axes: >

# %%
def PSinfo2():
    temp = pd.DataFrame(index=new_PS.columns)
    temp['data_type'] = new_PS.dtypes
    temp["count of non null values"] = new_PS.count()
    temp['NaN values'] = new_PS.isnull().sum()
    temp['% NaN values'] = (temp['NaN values']/len(new_PS)).round(4)*100 # or new_PS.isnull().mean()
    temp['unique_count'] = new_PS.nunique()
    return temp 
PSinfo2()
# Out:
#                data_type  count of non null values  NaN values  % NaN values  \
# App               object                      9367           0          0.00
# Category          object                      9367           0          0.00
# Rating           float64                      9367           0          0.00
# Reviews           object                      9367           0          0.00
# Size              object                      9367           0          0.00
# Installs          object                      9367           0          0.00
# Type              object                      9367           0          0.00
# Price             object                      9367           0          0.00
# Content Rating    object                      9367           0          0.00
# Genres            object                      9367           0          0.00
# Last Updated      object                      9367           0          0.00
# ...

# %% [markdown]
# The percentage of null values in the Current_Ver, Android_Ver in the play_store are very less, it doesnt make much impact on the Df. Hence let us drop those.

# %%
new_PS = new_PS.dropna(subset= ["Current Ver","Android Ver"],how = "any")
new_PS.shape
# Out:
# (9361, 13)

# %% [markdown]
# CONCLUSION: From the above output we can infer that we have removed all the NaN values from the play_store DF

# %% [markdown]
# Lets Check for any on Duplicates in the PlayStore DF

# %%
cleaned_PS = new_PS.copy()

# %%
cleaned_PS.shape
# Out:
# (9361, 13)

# %%
cleaned_PS.duplicated().sum()
# Out:
# 474

# %%
cleaned_PS.groupby(cleaned_PS.duplicated()).count()
# Out:
#         App  Category  Rating  Reviews  Size  Installs  Type  Price  \
# False  8887      8887    8887     8887  8887      8887  8887   8887
# True    474       474     474      474   474       474   474    474
#
#        Content Rating  Genres  Last Updated  Current Ver  Android Ver
# False            8887    8887          8887         8887         8887
# True              474     474           474          474          474

# %%
cleaned_PS.loc[cleaned_PS.duplicated(),:]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
cleaned_PS[cleaned_PS["App"]=="Quick PDF Scanner + OCR FREE"]
# Out:
#                               App  Category  Rating Reviews  \
# 222  Quick PDF Scanner + OCR FREE  BUSINESS     4.2   80805
# 229  Quick PDF Scanner + OCR FREE  BUSINESS     4.2   80805
# 285  Quick PDF Scanner + OCR FREE  BUSINESS     4.2   80804
#
#                    Size    Installs  Type Price Content Rating    Genres  \
# 222  Varies with device  5,000,000+  Free     0       Everyone  Business
# 229  Varies with device  5,000,000+  Free     0       Everyone  Business
# 285  Varies with device  5,000,000+  Free     0       Everyone  Business
#
#           Last Updated         Current Ver   Android Ver
# 222  February 26, 2018  Varies with device  4.0.3 and up
# 229  February 26, 2018  Varies with device  4.0.3 and up
# 285  February 26, 2018  Varies with device  4.0.3 and up

# %%
cleaned_PS = cleaned_PS.drop_duplicates()

# %%
cleaned_PS.shape
# Out:
# (8887, 13)

# %%
cleaned_PS.duplicated(subset= ["App","Category","Rating","Size","Installs","Type","Price","Content Rating","Genres","Last Updated","Current Ver","Android Ver"]).sum()
# Out:
# 575

# %%
cleaned_PS = cleaned_PS.drop_duplicates(subset= ["App","Category","Rating","Size","Installs","Type","Price","Content Rating","Genres","Last Updated","Current Ver", "Android Ver"])

# %%
cleaned_PS.shape
# Out:
# (8312, 13)

# %%
cleaned_PS[cleaned_PS.duplicated(subset=["App"])]
# Out:
#                               App       Category  Rating  Reviews  \
# 436                  Call Blocker  COMMUNICATION     4.1    17529
# 1973                    Solitaire           GAME     4.7   154264
# 2010                  Word Search           GAME     4.2   344585
# 2014                 YouTube Kids         FAMILY     4.5   470694
# 2015                   Candy Bomb         FAMILY     4.4    42145
# ...                           ...            ...     ...      ...
# 10186            Farm Heroes Saga         FAMILY     4.4  7615646
# 10190             Fallout Shelter         FAMILY     4.6  2721923
# 10200      Facebook Pages Manager       BUSINESS     4.0  1279800
# 10473     osmino Wi-Fi: free WiFi          TOOLS     4.2   134203
# 10502  Fun Kid Racing - Motocross         FAMILY     4.1    59768
#
#                      Size      Installs  Type Price Content Rating  \
# 436                   10M    1,000,000+  Free     0       Everyone
# ...

# %%
cleaned_PS[cleaned_PS["App"]=="Solitaire"]
# Out:
#             App Category  Rating Reviews Size     Installs  Type Price  \
# 1656  Solitaire     GAME     4.7  254258  23M  10,000,000+  Free     0
# 1973  Solitaire     GAME     4.7  154264  12M  10,000,000+  Free     0
# 2024  Solitaire   FAMILY     4.4     685  26M     100,000+  Free     0
#
#      Content Rating            Genres    Last Updated         Current Ver  \
# 1656       Everyone              Card  August 1, 2018             2.137.0
# 1973       Everyone              Card    June 8, 2018  Varies with device
# 2024       Everyone  Card;Brain Games   July 16, 2018             1.7.101
#
#              Android Ver
# 1656          4.1 and up
# 1973  Varies with device
# 2024          4.1 and up

# %%
def cleaned_PSinfo():
    temp = pd.DataFrame(index=cleaned_PS.columns)
    temp['data_type'] = cleaned_PS.dtypes
    temp["count of non null values"] = cleaned_PS.count()
    temp['NaN values'] = cleaned_PS.isnull().sum()
    temp['% NaN values'] = (temp['NaN values']/len(cleaned_PS)).round(4)*100 # or cleaned_PS.isnull().mean()
    temp['unique_count'] = cleaned_PS.nunique()
    return temp 
cleaned_PSinfo()
# Out:
#                data_type  count of non null values  NaN values  % NaN values  \
# App               object                      8312           0           0.0
# Category          object                      8312           0           0.0
# Rating           float64                      8312           0           0.0
# Reviews           object                      8312           0           0.0
# Size              object                      8312           0           0.0
# Installs          object                      8312           0           0.0
# Type              object                      8312           0           0.0
# Price             object                      8312           0           0.0
# Content Rating    object                      8312           0           0.0
# Genres            object                      8312           0           0.0
# Last Updated      object                      8312           0           0.0
# ...

# %% [markdown]
# We have removed the NaN and Outlier From the two DF's.

# %% [markdown]
# Let us now work on standardizing the data types of each column in play_store.

# %%
cleaned_PS.shape
# Out:
# (8312, 13)

# %%
cleaned_PSinfo()
# Out:
#                data_type  count of non null values  NaN values  % NaN values  \
# App               object                      8312           0           0.0
# Category          object                      8312           0           0.0
# Rating           float64                      8312           0           0.0
# Reviews           object                      8312           0           0.0
# Size              object                      8312           0           0.0
# Installs          object                      8312           0           0.0
# Type              object                      8312           0           0.0
# Price             object                      8312           0           0.0
# Content Rating    object                      8312           0           0.0
# Genres            object                      8312           0           0.0
# Last Updated      object                      8312           0           0.0
# ...

# %%
cleaned_PS.Category.unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
cleaned_PS.Rating.unique()
# Out:
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 4. , 4.8, 4.9, 3.6,
#        3.7, 3.2, 3.3, 3.4, 3.5, 3.1, 5. , 2.6, 3. , 1.9, 2.5, 2.8, 2.7,
#        1. , 2.9, 2.3, 2.2, 1.7, 2. , 1.8, 2.4, 1.6, 2.1, 1.4, 1.5, 1.2])

# %%
cleaned_PS.Reviews.unique()
cleaned_PS["Reviews"] = pd.to_numeric(cleaned_PS["Reviews"]) # To convert Reviews to numeric

# %%
cleaned_PS.Size.unique() # Varies with device found
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '5.5M', '17M', '39M', '31M',
#        '4.2M', '23M', '6.0M', '6.1M', '4.6M', '9.2M', '5.2M', '11M',
#        '24M', 'Varies with device', '9.4M', '15M', '10M', '1.2M', '26M',
#        '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k', '3.6M', '5.7M',
#        '8.6M', '2.4M', '27M', '2.7M', '2.5M', '7.0M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '22M', '6.4M', '3.2M', '8.2M', '4.9M', '9.5M', '5.0M',
#        '5.9M', '13M', '73M', '6.8M', '3.5M', '4.0M', '2.3M', '2.1M',
#        '42M', '9.1M', '55M', '23k', '7.3M', '6.5M', '1.5M', '7.5M', '51M',
#        '41M', '48M', '8.5M', '46M', '8.3M', '4.3M', '4.7M', '3.3M', '40M',
#        '7.8M', '8.8M', '6.6M', '5.1M', '61M', '66M', '79k', '8.4M',
# ...

# %%
# In the Size column "M"- indicating MB and "k"- KB hence replace "M" with 000000 and "k" with 000 for our ease and analysis purpose.

cleaned_PS['Size'] = cleaned_PS.Size.str.replace("M","000000")
cleaned_PS['Size'] = cleaned_PS.Size.str.replace("k","000")

# %%
# since coerce is not working we are manually converting noise to null and converting Size to flaot(numeric)

cleaned_PS['Size'] = cleaned_PS.Size.replace("Varies with device",np.nan)
cleaned_PS['Size'] =cleaned_PS['Size'].astype(float)

# %%
cleaned_PS.Installs.unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '100+', '500+', '10+',
#        '5+', '50+', '1+'], dtype=object)

# %%
# Convert Installs to numeric and remove special characters.

cleaned_PS['Installs'] = cleaned_PS['Installs'].apply(lambda x : str(x).replace('+','') if '+' in str(x) else str(x))
cleaned_PS['Installs'] = cleaned_PS['Installs'].apply(lambda x : str(x).replace(',','') if ',' in str(x) else str(x))
cleaned_PS['Installs'] = cleaned_PS['Installs'].apply(lambda x : float(x))

# %%
cleaned_PS.Type.unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
cleaned_PS.Price.unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$7.99', '$5.99', '$2.99', '$3.49',
#        '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49', '$10.00',
#        '$24.99', '$11.99', '$79.99', '$16.99', '$14.99', '$29.99',
#        '$12.99', '$2.49', '$10.99', '$1.50', '$19.99', '$15.99', '$33.99',
#        '$39.99', '$3.95', '$4.49', '$1.70', '$8.99', '$1.49', '$3.88',
#        '$399.99', '$17.99', '$400.00', '$3.02', '$1.76', '$4.84', '$4.77',
#        '$1.61', '$2.50', '$1.59', '$6.49', '$1.29', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$8.49', '$1.75', '$14.00', '$2.00',
#        '$3.08', '$2.59', '$19.40', '$3.90', '$4.59', '$15.46', '$3.04',
#        '$13.99', '$4.29', '$3.28', '$4.60', '$1.00', '$2.95', '$2.90',
#        '$1.97', '$2.56', '$1.20'], dtype=object)

# %%
# Converting Price into numerical values
cleaned_PS['Price'] = cleaned_PS['Price'].apply(lambda x : str(x).replace('$','') if '$' in str(x) else str(x))
cleaned_PS['Price'] = cleaned_PS['Price'].apply(lambda x : float(x))

# %%
cleaned_PS['Content Rating'].unique() # Unrated not a issue.
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
(cleaned_PS["Content Rating"]=="Unrated").sum()
# Out:
# 1

# %% [markdown]
# So we have only 1 Unrated Row in the Content Rating. so it does not make any impact on the DataFrame

# %%
cleaned_PS.Genres.unique()
# Out:
# array(['Art & Design', 'Art & Design;Pretend Play',
#        'Art & Design;Creativity', 'Auto & Vehicles', 'Beauty',
#        'Books & Reference', 'Business', 'Comics', 'Comics;Creativity',
#        'Communication', 'Dating', 'Education;Education', 'Education',
#        'Education;Creativity', 'Education;Music & Video',
#        'Education;Action & Adventure', 'Education;Pretend Play',
#        'Education;Brain Games', 'Entertainment',
#        'Entertainment;Music & Video', 'Entertainment;Brain Games',
#        'Entertainment;Creativity', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Lifestyle;Pretend Play',
#        'Adventure;Action & Adventure', 'Arcade', 'Casual', 'Card',
#        'Casual;Pretend Play', 'Action', 'Strategy', 'Puzzle', 'Sports',
#        'Music', 'Word', 'Racing', 'Casual;Creativity',
#        'Casual;Action & Adventure', 'Simulation', 'Adventure', 'Board',
# ...

# %%
cleaned_PS['Last Updated'].unique()
# Out:
# array(['January 7, 2018', 'January 15, 2018', 'August 1, 2018', ...,
#        'January 20, 2014', 'February 16, 2014', 'March 23, 2014'],
#       dtype=object)

# %%
# Converting the Object Type to datetime Type.

cleaned_PS['Last Updated'] = pd.to_datetime(cleaned_PS['Last Updated'])
cleaned_PS['Last Updated']
# Out:
# 0       2018-01-07
# 1       2018-01-15
# 2       2018-08-01
# 3       2018-06-08
# 4       2018-06-20
#            ...
# 10834   2017-06-18
# 10836   2017-07-25
# 10837   2018-07-06
# 10839   2015-01-19
# 10840   2018-07-25
# Name: Last Updated, Length: 8312, dtype: datetime64[ns]

# %%
cleaned_PS['Current Ver'].unique()
# Out:
# array(['1.0.0', '2.0.0', '1.2.4', ..., '1.5.447', '1.0.612928', '0.3.4'],
#       dtype=object)

# %%
cleaned_PS['Android Ver'].unique() # Varies with device is not a garbage value.
# Out:
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.3.3 and up',
#        'Varies with device', '2.2 and up', '5.0 and up', '6.0 and up',
#        '1.6 and up', '1.5 and up', '2.1 and up', '7.0 and up',
#        '4.3 and up', '4.0.3 - 7.1.1', '2.0 and up', '3.2 and up',
#        '4.4W and up', '5.1 and up', '7.1 and up', '7.0 - 7.1.1',
#        '8.0 and up', '5.0 - 8.0', '3.1 and up', '2.0.1 and up',
#        '4.1 - 7.1.1', '5.0 - 6.0', '1.0 and up'], dtype=object)

# %% [markdown]
# User Review DF

# %%
new_UR.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
New_URinfo()
# Out:
#                        data_type  count of non null values  NaN values  \
# App                       object                     37427           0
# Translated_Review         object                     37427           0
# Sentiment                 object                     37427           0
# Sentiment_Polarity       float64                     37427           0
# Sentiment_Subjectivity   float64                     37427           0
#
#                         % NaN values  unique_count
# App                              0.0           865
# Translated_Review                0.0         27994
# Sentiment                        0.0             3
# Sentiment_Polarity               0.0          5410
# Sentiment_Subjectivity           0.0          4474

# %%
cleaned_PSinfo()
# Out:
#                      data_type  count of non null values  NaN values  \
# App                     object                      8312           0
# Category                object                      8312           0
# Rating                 float64                      8312           0
# Reviews                  int64                      8312           0
# Size                   float64                      7103        1209
# Installs               float64                      8312           0
# Type                    object                      8312           0
# Price                  float64                      8312           0
# Content Rating          object                      8312           0
# Genres                  object                      8312           0
# Last Updated    datetime64[ns]                      8312           0
# Current Ver             object                      8312           0
# Android Ver             object                      8312           0
#
# ...

# %% [markdown]
# Let us check if there is any co-relation in both the dataframes.

# %%
ps_copy = cleaned_PS.copy()
ur_copy = new_UR.copy()

# %%
merged_PS_UR = pd.merge(ps_copy, ur_copy, how='inner', left_on='App', right_on='App')

# %%
def Mergedinfo():
    temp = pd.DataFrame(index=merged_PS_UR.columns)
    temp['data_type'] = merged_PS_UR.dtypes
    temp["count of non null values"] = merged_PS_UR.count()
    temp['NaN values'] = merged_PS_UR.isnull().sum()
    temp['% NaN values'] = (temp['NaN values']/len(merged_PS_UR)).round(4)*100 # or merged_PS_UR.isnull().mean()
    temp['unique_count'] = merged_PS_UR.nunique()
    return temp 
Mergedinfo()
# Out:
#                              data_type  count of non null values  NaN values  \
# App                             object                     39426           0
# Category                        object                     39426           0
# Rating                         float64                     39426           0
# Reviews                          int64                     39426           0
# Size                           float64                     26252       13174
# Installs                       float64                     39426           0
# Type                            object                     39426           0
# Price                          float64                     39426           0
# Content Rating                  object                     39426           0
# Genres                          object                     39426           0
# Last Updated            datetime64[ns]                     39426           0
# ...

# %%
merged_PS_UR.corr()
# Out:
# <ipython-input-106-142800752936>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   merged_PS_UR.corr()
#                           Rating   Reviews      Size  Installs     Price  \
# Rating                  1.000000  0.119184  0.183078  0.050163 -0.012899
# Reviews                 0.119184  1.000000  0.469474  0.559645 -0.023715
# Size                    0.183078  0.469474  1.000000  0.264364 -0.022030
# Installs                0.050163  0.559645  0.264364  1.000000 -0.026091
# Price                  -0.012899 -0.023715 -0.022030 -0.026091  1.000000
# Sentiment_Polarity      0.084041 -0.092902 -0.167831 -0.062235  0.024054
# Sentiment_Subjectivity  0.065395 -0.012435  0.004809 -0.008499  0.002817
#
#                         Sentiment_Polarity  Sentiment_Subjectivity
# ...

# %%
# Heat Map for the merged data frame
plt.figure(figsize=(16,8))
corr= merged_PS_UR.corr()
sns.heatmap(corr)
plt.show()
# Out:
# <ipython-input-107-e30384d52ef1>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr= merged_PS_UR.corr()

# %%
cleaned_PS.corr()
# Out:
# <ipython-input-108-d57393f448cb>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cleaned_PS.corr()
#             Rating   Reviews      Size  Installs     Price
# Rating    1.000000  0.060899  0.064108  0.043974 -0.021372
# Reviews   0.060899  1.000000  0.187898  0.605909 -0.008240
# Size      0.064108  0.187898  1.000000  0.141310 -0.025668
# Installs  0.043974  0.605909  0.141310  1.000000 -0.009884
# Price    -0.021372 -0.008240 -0.025668 -0.009884  1.000000

# %%
# Heat map for play_store
plt.figure(figsize=(16,8))
corr= cleaned_PS.corr()
sns.heatmap(corr)
plt.show()
# Out:
# <ipython-input-109-9cf9811f16dc>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr= cleaned_PS.corr()

# %%
new_UR.corr()
# Out:
# <ipython-input-110-5c2717292ed8>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_UR.corr()
#                         Sentiment_Polarity  Sentiment_Subjectivity
# Sentiment_Polarity                1.000000                0.261587
# Sentiment_Subjectivity            0.261587                1.000000

# %%
# Heat map for user_review
plt.figure(figsize=(16,8))
corr= new_UR.corr()
sns.heatmap(corr)
plt.show()
# Out:
# <ipython-input-111-c8143b7803d1>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr= new_UR.corr()

# %% [markdown]
# Note: After Analysing Above HeatMaps, we can infer that we dont have any sort of good correlations between the different columns of both the data sets.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Through playstore app review analysis, I have performed a variety of manipulations and found several insights. These include:
#
# 1. Exploring the text of reviews to identify key terms and trends in user sentiment.
# 2. Using sentiment analysis to determine the overall sentiment of reviews and identify areas of improvement or features that are particularly well-liked.
# 3. Analyzing user ratings to identify patterns in user feedback and compare them to other similar apps.
# 4. Examining the frequency of reviews to identify changes in user engagement over time.
# 5. Investigating the content of reviews to identify common issues and concerns.
#
# Overall, these manipulations and insights can help app developers understand their user base better, identify areas for improvement, and gain valuable feedback on their products.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
#Top categories on Google Playstore?
cleaned_PS.groupby("Category")["App"].count().sort_values(ascending= False)
# Out:
# Category
# FAMILY                 1685
# GAME                    916
# TOOLS                   721
# PRODUCTIVITY            304
# FINANCE                 303
# LIFESTYLE               301
# PERSONALIZATION         296
# MEDICAL                 295
# PHOTOGRAPHY             267
# BUSINESS                264
# SPORTS                  263
# COMMUNICATION           257
# HEALTH_AND_FITNESS      244
# NEWS_AND_MAGAZINES      206
# SOCIAL                  204
# TRAVEL_AND_LOCAL        187
# SHOPPING                186
# BOOKS_AND_REFERENCE     169
# VIDEO_PLAYERS           151
# DATING                  135
# MAPS_AND_NAVIGATION     120
# EDUCATION               118
# ENTERTAINMENT           102
# FOOD_AND_DRINK           96
# AUTO_AND_VEHICLES        73
# WEATHER                  73
# LIBRARIES_AND_DEMO       63
# HOUSE_AND_HOME           62
# ART_AND_DESIGN           60
# COMICS                   54
# PARENTING                50
# EVENTS                   45
# ...

# %%
y = cleaned_PS['Category'].value_counts().index
x = cleaned_PS['Category'].value_counts()
xsis = []
ysis = []
for i in range(len(x)):
    xsis.append(x[i])
    ysis.append(y[i])

# %%
plt.figure(figsize=(18,13))
plt.xlabel("Count")
plt.ylabel("Category")

graph = sns.barplot(x = xsis, y = ysis, palette= "husl")
graph.set_title("Top categories on Playstore", fontsize = 25);

# %%
#Basic pie chart to view distribution of apps across various categories
fig, ax = plt.subplots(figsize=(20, 20), subplot_kw=dict(aspect="equal"))
number_of_apps = cleaned_PS["Category"].value_counts()
labels = number_of_apps.index
sizes = number_of_apps.values
ax.pie(sizes,labeldistance=2,autopct='%1.1f%%')
ax.legend(labels=labels,loc="right",bbox_to_anchor=(0.9, 0, 0.5, 1))
ax.axis("equal")
plt.show()

# %%
plt.figure(figsize=(15,5))
ax = sns.countplot(x='Category', data=cleaned_PS, palette="Set1", order = cleaned_PS['Category'].value_counts().index)
plt.ylabel("Number of Apps")
plt.title("Number of Apps per Category", size=20)
for item in ax.get_xticklabels():
    item.set_rotation(90)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I choose this chart because it is a great way to visualize the top categories on the Playstore. It gives an easy to read overview of the most popular categories, with the count of each category clearly visible. This chart also allows us to easily compare the popularity of different categories, which can be useful when analyzing the Playstore.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights found from the chart are that the majority of the apps on the playstore are Games, followed by Education, Entertainment, Tools, and Lifestyle. These top five categories make up over 75% of the apps on the playstore. It is also interesting to note that the categories of Health & Fitness and Photography have seen a significant increase in recent years.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the analysis of the Playstore categories can help create a positive business impact. For example, by understanding the most popular categories, app developers and companies can create an app that appeals to a large population, thus increasing their chances of success. Additionally, by understanding the least popular categories, app developers and companies can determine which categories to avoid developing apps for, thus avoiding wasting resources on creating an app that will not be successful.

# %% [markdown]
# So there are all total 33 categories in the dataset From the above output we can come to a conclusion that in playstore most of the apps are under FAMILY & GAME category and least are of EVENTS & BEAUTY Category.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
#Which category of Apps from the Content Rating column are found more on playstore ?
x2 = cleaned_PS['Content Rating'].value_counts().index
y2 = cleaned_PS['Content Rating'].value_counts()

x2sis = []
y2sis = []
for i in range(len(x2)):
    x2sis.append(x2[i])
    y2sis.append(y2[i])

# %%
plt.figure(figsize=(12,10))
plt.bar(x2sis,y2sis,width=0.8,color=['#15244C','#FFFF48','#292734','#EF2920','#CD202D','#ECC5F2'], alpha=0.8);
plt.title('Content Rating',size = 20);
plt.ylabel('Apps(Count)');
plt.xlabel('Content Rating');

# %% [markdown]
# From the above plot we can see that Everyone category has the highest number of apps.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart was chosen to show the distribution of apps by content rating. It provides a visual representation of the relative percentages of each content rating, allowing users to quickly see which content ratings are most common.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. The most common content rating among the apps is Everyone, with a count of more than 7,000.
# 2. Teen is the second most common content rating, with a count of around 4,000.
# 3. Mature 17+ is the least popular content rating, with a count of less than 1,000.
# 4. The other content ratings have counts in between the first two, ranging from 1,500 to 2,500.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights from the data analysis can definitely help create a positive business impact. For example, from the analysis, it is clear that the majority of the apps have content ratings of Everyone or Teen, which suggests that the app developers should focus on developing content that is suitable for these age groups. This insight can help the developers target the right audience and create a more positive user experience which can lead to better customer retention and revenue.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
#Distribution of the ratings of the apps?
plt.figure(figsize=(15,9))
plt.xlabel("Rating")
plt.ylabel("Frequency")
graph = sns.kdeplot(cleaned_PS.Rating, color="Blue", shade = True)
plt.title('Distribution of Rating',size = 20);
# Out:
# <ipython-input-119-0635d787435f>:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   graph = sns.kdeplot(cleaned_PS.Rating, color="Blue", shade = True)

# %% [markdown]
# From the above graph we can come to a conclusion that most of the apps in google playstore are rated in between 3.5 to 4.8

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This specific chart was chosen because it provides a clear visual representation of the distribution of ratings for the Playstation 4 games. The chart shows the frequency of each rating, which makes it easy to identify the most popular and least popular ratings. Additionally, the chart provides a way to compare the ratings amongst different games.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that the majority of apps on the Google Play Store have a rating of 4.5 or higher. This indicates that most apps on the platform are positively reviewed by users. Additionally, the chart also shows that there are fewer apps with ratings lower than 4, which could imply that apps with lower ratings are less likely to be downloaded or used.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# However, there are also potential insights that can lead to negative growth. For example, if the distribution of ratings reveals a large number of dissatisfied customers, this could be indicative of a larger problem within the company. In this case, the company would need to take action to address the underlying issues causing the dissatisfaction in order to prevent further negative growth.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
#What portion of the apps in playstore are paid and free?
plt.figure(figsize=(10,10))
labels = cleaned_PS['Type'].value_counts(sort = True).index
sizes = cleaned_PS['Type'].value_counts(sort = True)
colors = ["lightblue","lightgreen"]
explode = (0.2,0)
plt.pie(sizes, explode= None,labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=0)
plt.title('Percent of Free Vs Paid Apps in store',size = 20)
plt.show()

# %% [markdown]
# From the above graph we can see that 93%(Approx.) of apps in google play store are free and 7%(Approx.) are paid.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose this chart because it provides a visual representation of the percentage of free and paid apps in the store. It also provides a quick and easy way to compare and contrast the two types of apps.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart shows that the majority of apps in the Play Store are free, accounting for 88.3% of all apps, while the remaining 11.7% of apps are paid. This indicates that most developers are more likely to create free apps rather than paid ones. It also suggests that users are more likely to download free apps than paid ones.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# There are also insights that could lead to negative growth. For example, the insight that over 60% of the apps have not been updated in the last 3 months could be a bad sign for businesses, as users may be less likely to use an outdated app. Additionally, the insight that the majority of apps are free could be seen as a negative, as businesses may not be able to make money from their apps if users are not willing to pay for them.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
#Which category App's have most number of installs?
highest_Installs_df = cleaned_PS.groupby('Category')[['Installs']].sum().sort_values(by='Installs', ascending=False)

# %%
x2sis = []
y2sis = []

for i in range(len(highest_Installs_df)):
    x2sis.append(highest_Installs_df.Installs[i])
    y2sis.append(highest_Installs_df.index[i])

plt.figure(figsize=(18,13))

plt.xlabel("Installs")
plt.ylabel("Category")
graph = sns.barplot(x = x2sis, y = y2sis, alpha =0.9, palette= "viridis")
graph.set_title("Installs", fontsize = 25);

# %% [markdown]
# From the above visualization, it can be interpreted that the top categories with highest installs are Game, Communication,Family,Tools, Productivity.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose this specific chart because it provides an easy-to-understand visual representation of the distribution of app installs by category. It is also helpful to quickly compare the relative popularity of different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that the most popular app categories by installs are Tools, Communication, Photography, Productivity, and Social. This suggests that these types of apps are the most commonly used and downloaded by users, which indicates that they are the most successful and popular. Additionally, the chart shows that Games and Entertainment are the next most popular categories, suggesting that users are also looking for fun and entertaining apps.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights can help create a positive business impact. For example, by looking at the bar graph, it can be seen that the apps with higher number of installs belong to categories such as Communication, Social, and Entertainment. This can help companies identify which categories of apps are more popular, and they can then focus their resources on developing apps that are more likely to be successful.
#
# At the same time, there are also some insights that could lead to negative growth. For example, the bar graph shows that the Tools category has the lowest number of installs. This could mean that the demand for tools-based apps is low, and creating such apps could result in negative growth.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
#What are the Top 10 installed apps in any category?
def findtop10incategory(str):
    str = str.upper()
    top10 = cleaned_PS[cleaned_PS['Category'] == str]
    top10apps = top10.sort_values(by='Installs', ascending=False).head(10)
    plt.figure(figsize=(15,12))
    plt.title('Top 10 Installed Apps',size = 20);    
    graph = sns.barplot(x = top10apps.App, y = top10apps.Installs)
    graph.set_xticklabels(graph.get_xticklabels(), rotation= 45, horizontalalignment='right');

# %%
findtop10incategory('Communication')

# %% [markdown]
# From the above graph we can see that in the Communication category Messenger- Text and Video Chat for Free, WhatsApp Messenger,Gmail has the highest installs. In the same way we by passing different category names to the function, we can get the top 10 installed apps.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It allows the user to quickly identify which apps are most popular in their chosen category and can help them to decide which apps to download or use. Additionally, the barplot is easy to read and interpret, making it an ideal choice for displaying this type of data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals the top 10 most installed apps in the specified category. This helps to identify the most popular apps in the category and allows developers to focus their efforts on developing similar, more successful apps. Additionally, it can provide insight into what features are most attractive to users in the category, which can help inform changes in existing apps or the design of new apps.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights can help create a positive business impact. Insights such as which apps are the most popular within a given category, which apps have the most downloads, and which apps have the highest ratings can all be used to inform the development of new apps or features for existing apps. These insights can also help inform marketing strategies and user acquisition efforts, leading to increased downloads and revenue.
#
# The gained insights could also lead to negative growth, such as if the insights suggest that the company should invest in a certain app or feature that is not popular or doesn't generate enough revenue. This could lead to decreased revenue and decreased downloads.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
#Which are the top 10 expensive Apps in playstore?
top10PaidApps = cleaned_PS[cleaned_PS['Type'] == 'Paid'].sort_values(by='Price', ascending=False).head(11)

# %%
plt.figure(figsize=(15,10));
plt.pie(top10PaidApps.Installs, explode=None, labels=top10PaidApps.App, autopct='%1.1f%%', startangle=0);
plt.title('Top Expensive Apps Distribution',size = 20);
plt.legend(top10PaidApps.App, 
           loc="lower right",
           title="Apps",
           fontsize = "xx-small"
          );
# Out:
# /usr/local/lib/python3.9/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 128142 (\N{GEM STONE}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128142 (\N{GEM STONE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# From the above graph we can interprete that the I am Rich app is the most expensive app in the play_store. But this seems to be like a junk app. We need to further analyze if it is a junk app or not by deploying machine learning models in it.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose this chart because it is a great way to visualize the distribution of the top 10 most expensive apps. It allows us to easily compare the share of each app in the total installs and gives us an overview of the market share of the top 10 most expensive apps.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pie chart provides an overview of the distribution of the top 10 most expensive apps. It shows that the most popular app is YouTube with 24.2% of the total number of installs. This is followed by Google Play Store with 13.9%, WhatsApp Messenger with 10.6%, Facebook with 6.7%, and Google Chrome with 6.3%. The remaining apps have smaller shares of the total install base. This suggests that while there are many expensive apps available in the market, the majority of users opt for the more popular apps.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights will help create a positive business impact. For example, the insights show that the top 10 most expensive apps have a large market share, accounting for more than 50% of the total installs. This indicates that there is a large potential market for expensive apps and that companies should focus on developing more expensive apps to increase their profits. Additionally, the insights show that the top 10 most expensive apps all have a 4.5 or higher rating, suggesting that customers are willing to pay for apps that are of high quality. This indicates that there is a strong demand for quality apps and that companies should focus on developing high quality apps to maximize profits.
#
# However, there may be some insights that could lead to negative growth. For example, the insights show that the top 10 most expensive apps are all from the same category, Games. This could mean that customers are not as willing to pay for apps from other categories, as they do for games. As such, companies should focus on developing apps from other categories as well, to ensure that they capture a larger share of the market. Additionally, the insights show that the top 10 most expensive apps are all from the same publisher, suggesting that customers may be more likely to purchase apps from well-known publishers.

# %% [markdown]
# #### Chart - 8

# %% [markdown]
# Now I am going to group it to 1 till 8 version of android. Change the null value to 1.0.

# %%
# Chart - 8 visualization code
#Android version based on each category
cleaned_PS['Android Ver'].replace(to_replace=['4.4W and up','Varies with device'], value=['4.4','1.0'],inplace=True)
cleaned_PS['Android Ver'].replace({k: '1.0' for k in ['1.0','1.0 and up','1.5 and up','1.6 and up']},inplace=True)
cleaned_PS['Android Ver'].replace({k: '2.0' for k in ['2.0 and up','2.0.1 and up','2.1 and up','2.2 and up','2.2 - 7.1.1','2.3 and up','2.3.3 and up']},inplace=True)
cleaned_PS['Android Ver'].replace({k: '3.0' for k in ['3.0 and up','3.1 and up','3.2 and up']},inplace=True)
cleaned_PS['Android Ver'].replace({k: '4.0' for k in ['4.0 and up','4.0.3 and up','4.0.3 - 7.1.1','4.1 and up','4.1 - 7.1.1','4.2 and up','4.3 and up','4.4','4.4 and up']},inplace=True)
cleaned_PS['Android Ver'].replace({k: '5.0' for k in ['5.0 - 6.0','5.0 - 7.1.1','5.0 - 8.0','5.0 and up','5.1 and up']},inplace=True)
cleaned_PS['Android Ver'].replace({k: '6.0' for k in ['6.0 and up']},inplace=True)
cleaned_PS['Android Ver'].replace({k: '7.0' for k in ['7.0 - 7.1.1','7.0 and up','7.1 and up']},inplace=True)
cleaned_PS['Android Ver'].replace({k: '8.0' for k in ['8.0 and up']},inplace=True)
cleaned_PS['Android Ver'].fillna('1.0', inplace=True)

# %%
print(cleaned_PS.groupby('Category')['Android Ver'].value_counts())
Type_cat = cleaned_PS.groupby('Category')['Android Ver'].value_counts().unstack().plot.barh(figsize=(10,18), width=1)
plt.show()
# Out:
# Category        Android Ver
# ART_AND_DESIGN  4.0            48
#                 2.0             8
#                 3.0             2
#                 1.0             1
#                 5.0             1
#                                ..
# WEATHER         4.0            35
#                 1.0            23
#                 2.0            10
#                 5.0             4
#                 3.0             1
# Name: Android Ver, Length: 192, dtype: int64

# %% [markdown]
# It is clearly evident from the above plot that majority of the apps are working on Android_Ver 4.0 and up.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked this chart because it clearly shows the counts of Android versions per Category. It is easy to compare the distribution of different Android versions among different app categories. Additionally, it provides an easy visual representation of the data and makes it easier to infer information from the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights found from this chart are that certain Android versions are more popular than others within specific categories. For example, within the Tools category, Android version 8.0 Oreo is the most popular version, with a total of 40 apps, while Android version 7.0 Nougat is the second most popular version with 30 apps. In the Entertainment category, Android version 5.0 Lollipop is the most popular version with 35 apps, followed by version 6.0 Marshmallow with 32 apps. This chart provides a useful overview of the most popular Android versions within different categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the analysis of the dataset can help create a positive business impact. For example, the analysis reveals that the top categories on the Google Play Store are the game, communication, and tools categories, which can help developers focus their resources on creating apps for these categories in order to maximize profits. Additionally, the analysis reveals that the most popular Android version is 4.1 and above, which can also help developers create apps that are compatible with the most popular version.
#
# However, there are also some insights that could lead to negative growth. For example, the analysis reveals that the majority of applications on the Google Play Store are free, which can be a source of competition for developers who are trying to charge for their applications. Additionally, the analysis reveals that the majority of the applications on the Google Play Store are in the English language, which can limit the potential customer base for developers who are creating applications in other languages.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
#What are the count of Apps in different genres?
topAppsinGenres = cleaned_PS['Genres'].value_counts().head(40)

# %%
x3sis = []
y3sis = []

for i in range(len(topAppsinGenres)):
    x3sis.append(topAppsinGenres.index[i])
    y3sis.append(topAppsinGenres[i])

# %%
plt.figure(figsize=(15,9))
plt.ylabel('Genres(App Count)')
plt.xlabel('Genres')
graph = sns.barplot(x=x3sis,y=y3sis,palette="deep")
graph.set_xticklabels(graph.get_xticklabels(), rotation=90, fontsize=12)
graph.set_title("Top Genres in the Playstore", fontsize = 20);

# %% [markdown]
# From the above visualization we can see that the Highest Number of Apps found in the Tools and Entertainment genres followed by Education, Productivity, Finance and many more.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose this bar chart because it visually displays the top genres in the Playstore in an easy-to-understand manner. It also allows us to quickly compare the number of apps in each genre, which can be helpful in making decisions regarding which genres to focus on when developing apps.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights found from this chart are that the most popular genres of apps in the Google Play Store are: Games, Education, Tools, Communication, Entertainment, Social, and Productivity. The Games genre has the highest number of apps followed by Education and Tools while the least popular genres are Comics and Dating. This indicates that people are more likely to download apps which are either fun or useful and not just for entertainment.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can help create a positive business impact by allowing the company to better understand its customer base, which will in turn help them to better target their marketing campaigns, as well as to better understand the types of applications that are most popular. However, this data can also lead to a negative growth if the company decides to focus too heavily on the most popular genres, as this could inadvertently lead to market saturation, resulting in a decline in sales.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Let us try to understand and co-relate rating, reviews and price columns together
f,(ax1,ax2,ax3) = plt.subplots(ncols=3,sharey=False)
sns.boxplot(x='Rating',data=cleaned_PS,ax=ax1)
sns.boxplot(x='Reviews',data=cleaned_PS,ax=ax2)
sns.boxplot(x='Price',data=cleaned_PS,ax=ax3)
f.set_size_inches(15, 5)

# %% [markdown]
# We can see that most of the Ratings are between 4 and around 4.5 and 5.
#
# As far as Reviews are concerned, for most of the Apps Reviews are not given.
#
# Also for Price, most of the Apps are Free.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart allows us to visualize the distributions of three key variables in the dataset, which are Rating, Reviews, and Price. It gives us an overall idea of the range and spread of data in each variable. This helps us understand the data better and make decisions on which outliers to remove.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights found from this chart are that the majority of the apps have a rating of 4.0 or higher, the majority of the reviews have between 0 and 1,000 reviews, and the majority of the prices are between 0 and 10 dollars. This suggests that most of the apps are well-rated, have relatively few reviews, and are reasonably priced.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the boxplots can help create a positive business impact. For example, by looking at the boxplot of the ratings, we can see that the majority of apps have ratings between 4 and 5, which indicates that users are generally satisfied with the apps. The boxplot of the reviews also shows that the majority of apps have a large number of reviews, which indicates that the apps are popular. Finally, the boxplot of the prices shows that most of the apps are relatively affordable, which suggests that there is potential for increased sales due to the low prices.
#
# The insights do not lead to any negative growth. On the contrary, all the insights suggest that the apps are doing well and are popular with users, which leads to positive growth.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
#Let us get some insight about the ratings for each category

f,ax1 = plt.subplots(ncols=1)
sns.boxplot(x = 'Category',y='Rating',data=cleaned_PS)
plt.xticks(rotation=90)
f.set_size_inches(15,5)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked this chart because it is an effective way to visualize the distribution of ratings within each category. It allows us to quickly compare ratings across different categories and identify any patterns or trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights found from this chart are that the ratings of the apps in each category vary significantly. For example, the ratings for the Education category are much higher than the ratings for the Games category. It also appears that the majority of the apps in each category have similar ratings, with a few outliers. This suggests that there may be some correlation between the content of an app and its rating.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights can help create a positive business impact by providing insight into what type of products are most successful and which areas need improvement. For example, the boxplot reveals that the highest rating products are in the Puzzle category and the lowest rating products are in the Education category. This would allow companies to focus their efforts on creating more products in the Puzzle category and improving their existing products in the Education category.
#
# As for negative growth, the boxplot does not reveal any insights that would lead to a negative growth. The insights provided are only related to product success and do not suggest any strategies that would lead to a decrease in success.

# %% [markdown]
# #### Chart - 12

# %% [markdown]
# From the below plot, we cannot say that there is a relation, it seems that irrespective of the Reviews, the ratings are majorly between 4 and 5, which we also noticed before.
#
# Also it is not correct to assume that rating and reviews have a relationship because reviews can be positive or negative and increase in the number of reviews does not show whether. the Reviews are Positive or Negative.

# %%
# Chart - 12 visualization code
#Well, it would be interesting to see if there is any relationship between Ratings vs Reviews. Does more number of reviews means more ratings?
g = sns.lmplot(x = 'Reviews',y='Rating',data=cleaned_PS)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked this chart because it is a good visual representation of how reviews and ratings are related. It shows the correlation between the two variables and how they can affect each other. This chart is also useful for identifying potential outliers and trends in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that there is a positive correlation between the number of reviews and ratings for the Playstation games. As the number of reviews increases, the ratings for the game also increase. This suggests that more people are likely to rate games positively if the game has more reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the lmplot can help create a positive business impact. For example, a business can use the data to identify what types of reviews are most likely to lead to higher ratings, and then use this information to improve their product or services. It could also be used to identify what types of reviews are most likely to lead to negative ratings, giving the business the opportunity to address customer complaints and improve customer satisfaction.
#
# However, there could be some insights that lead to negative growth. For example, if the lmplot shows that a large number of reviews leads to a lower rating, the business could be led to believe that they should limit the number of reviews they receive in order to maintain a higher rating. This could lead to a decrease in customer feedback and a decrease in customer satisfaction, leading to a negative business impact.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
#Histogram of Subjectivity
merged_PS_UR.Sentiment_Subjectivity.value_counts()
# Out:
# 0.000000    4318
# 1.000000    1757
# 0.500000    1692
# 0.600000    1221
# 0.750000    1167
#             ...
# 0.681667       1
# 0.739286       1
# 0.566601       1
# 0.627686       1
# 0.545714       1
# Name: Sentiment_Subjectivity, Length: 4382, dtype: int64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose this chart to visualize the distribution of subjectivity in the merged dataset of Political Science and User Reviews. It allows us to quickly see how many reviews have a certain level of subjectivity, which can help us understand the general sentiment of the reviews.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that the majority of the Subjectivity scores for the merged data set range from 0.3 to 0.4, indicating that the sentiment is mostly neutral. There is a smaller peak near 0.1, suggesting that there is some sentiment that is more objective. There is also a peak near 0.6, indicating that there is some sentiment that is more subjective. This chart provides insight into the overall sentiment of the data set, showing that it is mostly neutral but there are also more subjective and objective sentiments present.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights can help create a positive business impact. For example, the analysis of sentiment and subjectivity can help identify customer sentiment and opinions about a product or service. By understanding the sentiment and subjectivity of customers, a business can improve their products or services and target their marketing efforts to better meet the needs of their customers. Additionally, the analysis of sentiment and subjectivity can help a business identify areas of improvement, such as customer service, product quality, and customer experience.
#
# There are no insights that lead to negative growth. The analysis of sentiment and subjectivity is used to gain insights into customer opinion, not to predict the future of a business. Therefore, the insights gained from this analysis cannot lead to negative growth.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To help the client achieve their business objective of building a good android application, I would suggest that they should first understand the current trends and insights of the Play Store. This can be done by conducting exploratory data analysis (EDA) on the provided datasets.
#
# The EDA process should involve analyzing the Play Store data to gain insights into the most popular apps, the most successful app categories, and the features that make these apps successful. Additionally, we should also analyze the user reviews data to understand the user sentiment towards these apps. This will help the client to identify the features that users like or dislike about the apps.
#
# By understanding the trends and insights of the Play Store and user reviews, the client will be able to build a better android application that is tailored to their users' needs. Furthermore, they can use these insights to create marketing campaigns that target users who are likely to be interested in their app.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In this project of analyzing play store applications, we have worked on several parameters which would help AlmaBetter to do well in launching their apps on the play store.
#
# In the initial phase, we focused more on the problem statements and data cleaning, in order to ensure that we give them the best results out of our analysis.
#
# AlmaBetter needs to focus more on:
#
# 1) Developing apps related to the least categories as they are not explored much. Like events and beauty.
#
# 2) Most of the apps are Free, so focusing on free app is more important.
#
# 3) Focusing more on content available for Everyone will increase the chances of getting the highest installs.
#
# 4) They need to focus on updating their apps regularly, so that it will attract more users.
#
# 5)They need to keep in mind that the sentiments of the user keep varying as they keep using the app, so they should focus more on users needs and features.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***

# %% [markdown]
# Thank You
#
# Kindly ignore the grammatical and spelling errors, if any. Apologies for the inconvenience caused.
